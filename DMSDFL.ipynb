# %% [markdown]
# # DFL Colab v2.5 - DSM Custom Build

# %% [markdown]
# ## Quick Setup

# %%
#@title Check GPU
# !nvidia-smi

# %%
#@title Import DeepFaceLab + Workspace

#Mount Google Drive as folder
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

#For TimeOut-Reconnector
import IPython
from google.colab import output

#Import DeepFaceLab local clone from Google Drive
print("\nImporting DeepFaceLab...")

# %cd "/content"
copy_cmd = "/content/drive/My\ Drive/DeepFaceLab.zip /content"
# !cp $copy_cmd
unzip_cmd=" -q DeepFaceLab.zip"
# !unzip $unzip_cmd    
# !rm "DeepFaceLab.zip"

print("\nDeepFaceLab imported!")

#Install requirements
print("\nInstalling requirements...\n")
# !pip install -r /content/DeepFaceLab/requirements-colab.txt
# !pip install --upgrade scikit-image
# !apt-get install cuda-10-0

print("\nRequirements installed!")

#Importing workspace from Google Drive
Archive_name=""
unzip_cmd=" -q "+Archive_name

print("\nImporting workspace...")
# %cd "/content"
copy_cmd = "--progress "+"/content/drive/My\ Drive/workspace.zip /content"
# !rsync $copy_cmd

print("\nUnzipping workspace...")
unzip_cmd=" -q workspace.zip"
# !unzip $unzip_cmd    
#!rm "workspace.zip" -- left undeleted for Training backup delta zip-adds

print("\nWorkspace imported!")

#Prevent timeout by auto-reconnecting
display(IPython.display.Javascript('''
function ClickConnect(){
  btn = document.querySelector("colab-connect-button")
  if (btn != null){
    console.log("Click colab-connect-button"); 
    btn.click() 
    }
  
  btn = document.getElementById('ok')
  if (btn != null){
    console.log("Click reconnect"); 
    btn.click() 
    }
  }
  
setInterval(ClickConnect,10000)
'''))
print("\nTimeout Reconnector activated!")

print("\nSetup DONE!")

# %%
#@title Import DeepFaceLab + Workspace > Train

#Mount Google Drive as folder
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

#For TimeOut-Reconnector
import IPython
from google.colab import output

#Import DeepFaceLab local clone from Google Drive
print("\nImporting DeepFaceLab...")

# %cd "/content"
copy_cmd = "/content/drive/My\ Drive/DeepFaceLab.zip /content"
# !cp $copy_cmd
unzip_cmd=" -q DeepFaceLab.zip"
# !unzip $unzip_cmd    
# !rm "DeepFaceLab.zip"

print("\nDeepFaceLab imported!")

#Install requirements
print("\nInstalling requirements...\n")
# !pip install -r /content/DeepFaceLab/requirements-colab.txt
# !pip install --upgrade scikit-image
# !apt-get install cuda-10-0

print("\nRequirements installed!")

#Importing workspace from Google Drive
Archive_name=""
unzip_cmd=" -q "+Archive_name

print("\nImporting workspace...")
# %cd "/content"
copy_cmd = "--progress "+"/content/drive/My\ Drive/workspace.zip /content"
# !rsync $copy_cmd

print("\nUnzipping workspace...")
unzip_cmd=" -q workspace.zip"
# !unzip $unzip_cmd    
#!rm "workspace.zip" -- left undeleted for Training backup delta zip-adds

print("\nWorkspace imported!")

#Prevent timeout by auto-reconnecting
display(IPython.display.Javascript('''
function ClickConnect(){
  btn = document.querySelector("colab-connect-button")
  if (btn != null){
    console.log("Click colab-connect-button"); 
    btn.click() 
    }
  
  btn = document.getElementById('ok')
  if (btn != null){
    console.log("Click reconnect"); 
    btn.click() 
    }
  }
  
setInterval(ClickConnect,10000)
'''))
print("\nTimeout Reconnector activated!")

print("\nSetup DONE!")

#Training
Model = "SAEHD" #@param ["SAEHD", "Quick96", "XSeg"]
Backup_every_hour = True #@param {type:"boolean"}
Silent_Start = False #@param {type:"boolean"}

print("\nInitiating Training ...\n")

# %cd "/content"

#Mount Google Drive as folder
from google.colab import drive
drive.mount('/content/drive')

import psutil, os, time

p = psutil.Process(os.getpid())
uptime = time.time() - p.create_time()

if (Backup_every_hour):
  if not os.path.exists('workspace.zip'):
    print("Creating workspace archive ...")
    # !zip -r -q workspace.zip workspace
    print("Archive created!")
  else:
    print("Archive exist!")

if (Backup_every_hour):
  print("Time to end session: "+str(round((43200-uptime)/3600))+" hours")
  backup_time = str(3600)
  backup_cmd = " --execute-program -"+backup_time+" \"import os; os.system('zip -r -q workspace.zip workspace/model'); os.system('cp /content/workspace.zip /content/drive/My\ Drive/'); print('Backed up!') \"" 
elif (round(39600-uptime) > 0):
  print("Time to backup: "+str(round((39600-uptime)/3600))+" hours")
  backup_time = str(round(39600-uptime))
  backup_cmd = " --execute-program "+backup_time+" \"import os; os.system('zip -r -q workspace.zip workspace'); os.system('cp /content/workspace.zip /content/drive/My\ Drive/'); print('Backed up!') \"" 
else:
  print("Session expires in less than an hour.")
  backup_cmd = ""
    
cmd = "DeepFaceLab/main.py train --training-data-src-dir workspace/data_src/aligned --training-data-dst-dir workspace/data_dst/aligned --pretraining-data-dir pretrain --model-dir workspace/model --model "+Model

if Model == "Quick96":
  cmd+= " --pretrained-model-dir pretrain_Q96"

if Silent_Start:
  cmd+= " --silent-start"

if (backup_cmd != ""):
  train_cmd = (cmd+backup_cmd)
else:
  train_cmd = (cmd)

# !python $train_cmd

# %%
#@title Import DeepFaceLab + Workspace > Merge

#Mount Google Drive as folder
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

#For TimeOut-Reconnector
import IPython
from google.colab import output

#Import DeepFaceLab local clone from Google Drive
print("\nImporting DeepFaceLab...")

# %cd "/content"
copy_cmd = "/content/drive/My\ Drive/DeepFaceLab.zip /content"
# !cp $copy_cmd
unzip_cmd=" -q DeepFaceLab.zip"
# !unzip $unzip_cmd    
# !rm "DeepFaceLab.zip"

print("\nDeepFaceLab imported!")

#Install requirements
print("\nInstalling requirements...\n")
# !pip install -r /content/DeepFaceLab/requirements-colab.txt
# !pip install --upgrade scikit-image
# !apt-get install cuda-10-0

print("\nRequirements installed!")

#Importing workspace from Google Drive
Archive_name=""
unzip_cmd=" -q "+Archive_name

print("\nImporting workspace...")
# %cd "/content"
copy_cmd = "--progress "+"/content/drive/My\ Drive/workspace.zip /content"
# !rsync $copy_cmd

print("\nUnzipping workspace...")
unzip_cmd=" -q workspace.zip"
# !unzip $unzip_cmd    
#!rm "workspace.zip" -- left undeleted for Training backup delta zip-adds

print("\nWorkspace imported!")

#Prevent timeout by auto-reconnecting
display(IPython.display.Javascript('''
function ClickConnect(){
  btn = document.querySelector("colab-connect-button")
  if (btn != null){
    console.log("Click colab-connect-button"); 
    btn.click() 
    }
  
  btn = document.getElementById('ok')
  if (btn != null){
    console.log("Click reconnect"); 
    btn.click() 
    }
  }
  
setInterval(ClickConnect,10000)
'''))
print("\nTimeout Reconnector activated!")

print("\nSetup DONE!")

#Merge
from pathlib import Path

Model = "SAEHD" #@param ["SAEHD", "Quick96" ]
ResultBitRate = "20" #@param {type:"string"}
ResultFileName = "result.mp4" #@param {type:"string"}
MaskFileName = MaskFileName = ResultFileName.split(".")[0]+"-mask."+ResultFileName.split(".")[1]
ResultFolderName = ResultFileName.split(".")[0]
ResultMaskFolderName = ResultFolderName+"_mask"
Include_Mask = True #@param {type:"boolean"}
Export_Format = "MP4" #@param ["MP4", "Frames" ]

#Merge
print("Initiating Merge ...\n")
# %cd "/content"

merge_cmd = "DeepFaceLab/main.py merge --input-dir workspace/data_dst --output-dir workspace/data_dst/merged --output-mask-dir workspace/data_dst/merged_mask --aligned-dir workspace/data_dst/aligned --model-dir workspace/model --model "+Model
# !python $merge_cmd

#Output
if (Export_Format == "MP4"):
  print("\nCombining merged frames to "+ResultFileName+" ...\n")

  output_cmd = "DeepFaceLab/main.py videoed video-from-sequence --input-dir workspace/data_dst/merged --output-file workspace/"+ResultFileName+" --reference-file workspace/data_dst.mp4 --bitrate "+ResultBitRate+" --include-audio"
  # !python $output_cmd

  if (Include_Mask):
    print("\nCombining merged_mask frames to "+MaskFileName+" ...\n")

    output_cmd = "DeepFaceLab/main.py videoed video-from-sequence --input-dir workspace/data_dst/merged_mask --output-file workspace/"+MaskFileName+" --reference-file workspace/data_dst.mp4 --bitrate "+ResultBitRate
    # !python $output_cmd

#Export to Drive
if (Export_Format == "MP4"):
  print("\nExporting "+ResultFileName+" to Drive ...\n")

  copy_cmd = "--progress "+"/content/workspace/"+ResultFileName+" /content/drive/My\ Drive/"
  # !rsync $copy_cmd

  if (Include_Mask):
    print("\nExporting "+MaskFileName+" to Drive ...\n")

    copy_cmd = "--progress "+"/content/workspace/"+MaskFileName+" /content/drive/My\ Drive/"
    # !rsync $copy_cmd

else:
  print("\nExporting merged frames to Drive ...\n")
  folderPath = "/content/drive/My Drive/"+ResultFolderName
  
  if not Path(folderPath).exists():
    print("\nCreating "+ResultFolderName+" folder in Drive ... ")
    mkdir_cmd = "/content/drive/My\ Drive/"+ResultFolderName
    # !mkdir $mkdir_cmd
  
  # %cd $folderPath
  print("\nCopying merged frames to "+ResultFolderName+" on Drive ... ")
  copy_cmd = "--progress "+"* /content/drive/My\ Drive/merged/"
  # !rsync $copy_cmd

  if (Include_Mask):
    print("\nExporting merged_mask frames to Drive ...\n")
    maskFolderPath = "/content/drive/My Drive/"+ResultMaskFolderName
    
    if not Path(maskFolderPath).exists():
      print("\nCreating "+ResultMaskFolderName+" folder in Drive ... ")
      mkdir_cmd = "/content/drive/My\ Drive/"+ResultMaskFolderName
      # !mkdir $mkdir_cmd
    
    # %cd $maskFolderPath
    print("\nCopying merged_mask frames to "+ResultMaskFolderName+" on Drive ... ")
    copy_cmd = "--progress "+"* /content/drive/My\ Drive/merged_mask/"
    # !rsync $copy_cmd

print("\nDONE!")

# %% [markdown]
# ## Install or Update DeepFaceLab

# %%
#@title Install or update DeepFaceLab from Github

Mode = "install" #@param ["install", "update"]

from pathlib import Path
if (Mode == "install"):
  # !git clone https://github.com/iperov/DeepFaceLab.git

  # fix linux warning
  # /usr/lib/python3.6/multiprocessing/semaphore_tracker.py:143: UserWarning: semaphore_tracker: There appear to be 1 leaked semaphores to clean up at shutdown
  fin = open("/usr/lib/python3.6/multiprocessing/semaphore_tracker.py", "rt")
  data = fin.read()
  data = data.replace('if cache:', 'if False:')
  fin.close()

  fin = open("/usr/lib/python3.6/multiprocessing/semaphore_tracker.py", "wt")
  fin.write(data)
  fin.close()
else:
  # %cd /content/DeepFaceLab
  # !git pull

# !pip install -r /content/DeepFaceLab/requirements-colab.txt
# !pip install --upgrade scikit-image
# !apt-get install cuda-10-0

if not Path("/content/pretrain").exists():
  print("Downloading CelebA faceset ... ")
  # !wget -q --no-check-certificate -r 'https://github.com/chervonij/DFL-Colab/releases/download/pretrain-CelebA/pretrain_CelebA.zip' -O /content/pretrain_CelebA.zip
  # !mkdir /content/pretrain
  # !unzip -q /content/pretrain_CelebA.zip -d /content/pretrain/
  # !rm /content/pretrain_CelebA.zip

if not Path("/content/pretrain_Q96").exists():
  print("Downloading Q96 pretrained model ...")
  # !wget -q --no-check-certificate -r 'https://github.com/chervonij/DFL-Colab/releases/download/Q96_model_pretrained/Q96_model_pretrained.zip' -O /content/pretrain_Q96.zip
  # !mkdir /content/pretrain_Q96
  # !unzip -q /content/pretrain_Q96.zip -d /content/pretrain_Q96/
  # !rm /content/pretrain_Q96.zip

if not Path("/content/workspace").exists():
  # !mkdir /content/workspace; mkdir /content/workspace/data_src; mkdir /content/workspace/data_src/aligned; mkdir /content/workspace/data_dst; mkdir /content/workspace/data_dst/aligned; mkdir /content/workspace/model  

import IPython
from google.colab import output

display(IPython.display.Javascript('''
 function ClickConnect(){
   btn = document.querySelector("colab-connect-button")
   if (btn != null){
     console.log("Click colab-connect-button"); 
     btn.click() 
     }
   
   btn = document.getElementById('ok')
   if (btn != null){
     console.log("Click reconnect"); 
     btn.click() 
     }
  }
  
setInterval(ClickConnect,60000)
'''))

print("\nDone!")

# %% [markdown]
# ## Manage workspace

# %%
#@title Import from Drive

Mode = "workspace" #@param ["workspace", "data_dst", "data_dst-aligned", "data_src", "data_src-aligned", "model"]

#Mount Google Drive as folder
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

def copy_and_unzip(path, filename):
  Archive_name=filename+".zip"
  
  # %cd $path
  copy_cmd = "--progress "+"/content/drive/My\ Drive/"+Archive_name+" "+path
  print("Copying "+Archive_name+" from Drive ...")
  # !rsync $copy_cmd
  
  unzip_cmd=" -q "+Archive_name
  print("Unzipping "+Archive_name+" ...")
  # !unzip $unzip_cmd    
  
  if filename == "workspace":
    print("Retaining copy of "+Archive_name+" ...")
  else:
    print("Removing copy of "+Archive_name+" ...")
    # !rm $Archive_name

if Mode == "workspace":
  copy_and_unzip("/content", "workspace")

elif Mode == "data_dst":
  copy_and_unzip("/content/workspace", "data_dst")
elif Mode == "data_dst-aligned":
  copy_and_unzip("/content/workspace/data_dst", "data_dst-aligned")

elif Mode == "data_src":
  copy_and_unzip("/content/workspace", "data_src")
elif Mode == "data_src-aligned":
  copy_and_unzip("/content/workspace/data_src", "data_src-aligned")

elif Mode == "model":
  copy_and_unzip("/content/workspace", "model")
  
print("DONE!")

# %%
#@title Export to Drive { form-width: "30%" }
Mode = "workspace" #@param ["workspace", "data_dst", "data_dst-aligned", "data_dst-aligned_debug", "data_dst-aligned + aligned_debug", "data_src", "data_src-aligned", "data_src-aligned_debug", "data_src-aligned + aligned_debug", "merged", "merged (folder copy)", "merged_mask", "merged_mask (folder copy)", "model", "result video", "result_mask video"]
Suffix = ".zip" #@param {type:"string"}

#Mount Google Drive as folder
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

from pathlib import Path

def zip_and_copy(path, folder):
  Archive_name = folder+Suffix
  zip_cmd="-r -q "+Archive_name+" "
  
  # %cd $path
  zip_cmd+=folder
  print("Creating zip archive: zip "+zip_cmd+" ...")
  # !zip $zip_cmd
  
  copy_cmd = "--progress "+" "+Archive_name+"  /content/drive/My\ Drive/"
  print("Copying "+Archive_name+" to Drive ...")
  # !rsync $copy_cmd
  
  if folder == "workspace":
    print("Retaining copy of "+Archive_name+" ...")
  else:
    print("Removing copy of "+Archive_name+" ...")
    # !rm $Archive_name


def copy_folder(path, folder):
  if not Path("/content/drive/My Drive/"+folder).exists():
    print("Creating "+folder+" folder in Drive ... ")
    mkdir_cmd = "/content/drive/My\ Drive/"+folder
    # !mkdir $mkdir_cmd

  # %cd $path
  print("Copying contents of "+folder+" to Drive ... ")
  copy_cmd = "--progress "+"* /content/drive/My\ Drive/merged_mask/"
  # !rsync $copy_cmd
  

if Mode == "workspace":
  zip_and_copy("/content", "workspace")

elif Mode == "data_dst":
  zip_and_copy("/content/workspace", "data_dst")
elif Mode == "data_dst-aligned":
  zip_and_copy("/content/workspace/data_dst", "aligned")
elif Mode == "data_dst-aligned_debug":
  zip_and_copy("/content/workspace/data_dst", "aligned_debug")
elif Mode == "data_dst-aligned + aligned_debug":
  zip_and_copy("/content/workspace/data_dst", "aligned")
  zip_and_copy("/content/workspace/data_dst", "aligned_debug")

elif Mode == "data_src":
  zip_and_copy("/content/workspace", "data_src")
elif Mode == "data_src-aligned":
  zip_and_copy("/content/workspace/data_src", "aligned")
elif Mode == "data_src-aligned_debug":
  zip_and_copy("/content/workspace/data_src", "aligned_debug")
elif Mode == "data_src-aligned + aligned_debug":
  zip_and_copy("/content/workspace/data_src", "aligned")
  zip_and_copy("/content/workspace/data_src", "aligned_debug")

elif Mode == "merged":
  zip_and_copy("/content/workspace/data_dst", "merged")
elif Mode == "merged_mask":
  zip_and_copy("/content/workspace/data_dst", "merged_mask")

elif Mode == "model":
  zip_and_copy("/content/workspace", "model")

elif Mode == "merged (folder copy)":
  copy_folder("/content/workspace/data_dst/merged", "merged")
elif Mode == "merged_mask (folder copy)":
  copy_folder("/content/workspace/data_dst/merged_mask", "merged_mask")

elif Mode == "result video":
  # !cp /content/workspace/result.mp4 /content/drive/My\ Drive/
elif Mode == "result_mask video":
  # !cp /content/workspace/result_mask.mp4 /content/drive/My\ Drive/
  
print("DONE!")

# %%
#@title Delete and recreate
Mode = "Delete and recreate workspace" #@param ["Delete and recreate workspace", "Delete data_dst ALL", "Delete data_dst", "Delete data_dst-aligned", "Delete data_dst-aligned_debug", "Delete data_src ALL", "Delete data_src", "Delete data_src-aligned", "Delete data_src-aligned_debug", "Delete merged + merged_mask", "Delete model"]

# %cd "/content" 

if Mode == "Delete and recreate workspace":
  cmd = "rm -r /content/workspace; rm -r /content/__MACOSX; mkdir /content/workspace; mkdir /content/workspace/data_src; mkdir /content/workspace/data_src/aligned; mkdir /content/workspace/data_dst; mkdir /content/workspace/data_dst/aligned; mkdir /content/workspace/model"  

elif Mode == "Delete data_dst ALL":
  cmd = "rm /content/workspace/data_dst/*.png || rm /content/workspace/data_dst/*.jpg"
  cmd = "rm -r /content/workspace/data_dst/aligned/*"
  cmd = "rm -r /content/workspace/data_dst/aligned_debug/*"
elif Mode == "Delete data_dst":
  cmd = "rm /content/workspace/data_dst/*.png || rm /content/workspace/data_dst/*.jpg"
elif Mode == "Delete data_dst-aligned":
  cmd = "rm -r /content/workspace/data_dst/aligned/*"
elif Mode == "Delete data_dst-aligned_debug":
  cmd = "rm -r /content/workspace/data_dst/aligned_debug/*"

elif Mode == "Delete data_src ALL":
  cmd = "rm /content/workspace/data_dst/*.png || rm /content/workspace/data_dst/*.jpg"
  cmd = "rm -r /content/workspace/data_dst/aligned/*"
  cmd = "rm -r /content/workspace/data_dst/aligned_debug/*"
elif Mode == "Delete data_src":
  cmd = "rm /content/workspace/data_src/*.png || rm -r /content/workspace/data_src/*.jpg"
elif Mode == "Delete data_src-aligned":
  cmd = "rm -r /content/workspace/data_src/aligned/*"
elif Mode == "Delete data_src-aligned_debug":
  cmd = "rm -r /content/workspace/data_src/aligned_debug/*"

elif Mode == "Delete merged + merged_mask":
  cmd = "rm -r /content/workspace/data_dst/merged; rm -r /content/workspace/data_dst/merged_mask"

elif Mode == "Delete model":
  cmd = "rm -r /content/workspace/model/*"
  
# !$cmd
print("DONE!")

# %% [markdown]
# ## Extract, sorting and faceset tools

# %%
#@title Extract > Detect > Update & Export Zip to Drive

import os

print("Extracting frames ...\n")

# %cd "/content"

#Extract frames
Video = "data_dst" #@param ["data_dst","data_src"]
Format = "jpg" #@param ["jpg","png"]
FPS = 0 #@param {type:"integer"}

cmd = "DeepFaceLab/main.py videoed extract-video"

if Video == "data_dst":
  cmd+= " --input-file workspace/data_dst.* --output-dir workspace/data_dst/ --output-ext "+Format+" --fps "+str(FPS)
else:
  cmd+= " --input-file workspace/data_src.* --output-dir workspace/data_src/ --output-ext "+Format+" --fps "+str(FPS)
  
# !python $cmd

print("\nDetecting faces ...\n")

#Detect faces
Data = Video
Detector = "S3FD (whole face)" #@param ["S3FD", "S3FD (whole face)"]
Debug = True #@param {type:"boolean"}

detect_type = "s3fd"
dbg = " --output-debug" if Debug else " --no-output-debug"

folder = "workspace/"+Data
folder_aligned = folder+"/aligned"

cmd = "DeepFaceLab/main.py extract --input-dir "+folder+" --output-dir "+folder_aligned
cmd+=" --detector "+detect_type+" --force-gpu-idxs 0"+dbg

if "whole face" in Detector:
  cmd+=" --face-type whole_face" 

# !python $cmd

#Update Zip
Update_workspace_zip = True #@param {type:"boolean"}
if (Update_workspace_zip):
  if not os.path.exists('workspace.zip'):
    print("\nworkspace.zip does not exist, creating ...")
    # !zip -r -q workspace.zip workspace
  else:
    zip_cmd = "-r -q workspace.zip workspace/"+Video
    print("\nUpdating /"+Video+" ALL into workspace.zip ...")
    # !zip $zip_cmd

#Export to Drive
Export_workspace_zip = True #@param {type:"boolean"}
if (Export_workspace_zip):
  print("\nExporting workspace.zip to Drive ...")
  copy_cmd = "--progress "+"/content/workspace.zip /content/drive/My\ Drive/"
  # !rsync $copy_cmd 

print("\nDONE!")

# %%
#@title Extract frames
Video = "data_dst" #@param ["data_dst","data_src"]
Format = "jpg" #@param ["jpg","png"]
FPS = 0 #@param {type:"integer"}

# %cd "/content"

cmd = "DeepFaceLab/main.py videoed extract-video"

if Video == "data_dst":
  cmd+= " --input-file workspace/data_dst.* --output-dir workspace/data_dst/ --output-ext "+Format+" --fps "+FPS
else:
  cmd+= " --input-file workspace/data_src.* --output-dir workspace/data_src/ --output-ext "+Format+" --fps "+FPS
  
# !python $cmd

# %%
#@title Denoise frames
Data = "data_src" #@param ["data_src", "data_dst"]
Factor = 1 #@param {type:"slider", min:1, max:20, step:1}

cmd = "DeepFaceLab/main.py videoed denoise-image-sequence --input-dir workspace/"+Data+" --factor "+str(Factor)

# %cd "/content"
# !python $cmd

# %%
#@title Detect faces
Data = "data_dst" #@param ["data_dst", "data_src"]
Detector = "S3FD (whole face)" #@param ["S3FD", "S3FD (whole face)"]
Debug = True #@param {type:"boolean"}

detect_type = "s3fd"
dbg = " --output-debug" if Debug else " --no-output-debug"

folder = "workspace/"+Data
folder_aligned = folder+"/aligned"

cmd = "DeepFaceLab/main.py extract --input-dir "+folder+" --output-dir "+folder_aligned
cmd+=" --detector "+detect_type+" --force-gpu-idxs 0"+dbg

if "whole face" in Detector:
  cmd+=" --face-type whole_face" 
# %cd "/content"
# !python $cmd

# %%
#@title Sort aligned
Data = "data_src" #@param ["data_src", "data_dst"]
sort_type = "hist" #@param ["blur", "face-yaw", "face-pitch", "face-source-rect-size", "hist", "hist-dissim", "brightness", "hue", "black", "origname", "oneface", "final", "final-faster", "absdiff"]

cmd = "DeepFaceLab/main.py sort --input-dir workspace/"+Data+"/aligned --by "+sort_type

# %cd "/content"
# !python $cmd

# %%
#@title Faceset Enhancer
Data = "data_src" #@param ["data_src", "data_dst"]

data_path = "/content/workspace/"+Data+"/aligned"
cmd = "/content/DeepFaceLab/main.py facesettool enhance --input-dir "+data_path
# !python $cmd

# %%
#@title Apply or remove XSeg mask to the faces
Mode = "Remove mask" #@param ["Apply mask", "Remove mask"]
Data = "data_src" #@param ["data_src", "data_dst"]

main_path = "/content/DeepFaceLab/main.py "
data_path = "/content/workspace/"+Data+"/aligned "
mode_arg = "apply " if Mode == "Apply mask" else "remove "
cmd = main_path+"xseg "+mode_arg+"--input-dir "+data_path
cmd += "--model-dir /content/workspace/model" if mode_arg == "apply " else ""

# !python $cmd

# %% [markdown]
# ## Train model

# %%
#@title Training
Model = "SAEHD" #@param ["SAEHD", "Quick96", "XSeg"]
Backup_every_hour = True #@param {type:"boolean"}
Silent_Start = False #@param {type:"boolean"}

# %cd "/content"

#Mount Google Drive as folder
from google.colab import drive
drive.mount('/content/drive')

import psutil, os, time

p = psutil.Process(os.getpid())
uptime = time.time() - p.create_time()

if (Backup_every_hour):
  if not os.path.exists('workspace.zip'):
    print("Creating workspace archive ...")
    # !zip -r -q workspace.zip workspace
    print("Archive created!")
  else:
    print("Archive exist!")

if (Backup_every_hour):
  print("Time to end session: "+str(round((43200-uptime)/3600))+" hours")
  backup_time = str(3600)
  backup_cmd = " --execute-program -"+backup_time+" \"import os; os.system('zip -r -q workspace.zip workspace/model'); os.system('cp /content/workspace.zip /content/drive/My\ Drive/'); print('Backed up!') \"" 
elif (round(39600-uptime) > 0):
  print("Time to backup: "+str(round((39600-uptime)/3600))+" hours")
  backup_time = str(round(39600-uptime))
  backup_cmd = " --execute-program "+backup_time+" \"import os; os.system('zip -r -q workspace.zip workspace'); os.system('cp /content/workspace.zip /content/drive/My\ Drive/'); print('Backed up!') \"" 
else:
  print("Session expires in less than an hour.")
  backup_cmd = ""
    
cmd = "DeepFaceLab/main.py train --training-data-src-dir workspace/data_src/aligned --training-data-dst-dir workspace/data_dst/aligned --pretraining-data-dir pretrain --model-dir workspace/model --model "+Model

if Model == "Quick96":
  cmd+= " --pretrained-model-dir pretrain_Q96"

if Silent_Start:
  cmd+= " --silent-start"

if (backup_cmd != ""):
  train_cmd = (cmd+backup_cmd)
else:
  train_cmd = (cmd)

# !python $train_cmd

# %% [markdown]
# ## Merge

# %%
#@title Merge & Export result video

from pathlib import Path

Model = "SAEHD" #@param ["SAEHD", "Quick96" ]
ResultBitRate = "20" #@param {type:"string"}
ResultFileName = "result.mp4" #@param {type:"string"}
MaskFileName = MaskFileName = ResultFileName.split(".")[0]+"-mask."+ResultFileName.split(".")[1]
ResultFolderName = ResultFileName.split(".")[0]
ResultMaskFolderName = ResultFolderName+"_mask"
Include_Mask = True #@param {type:"boolean"}
Export_Format = "MP4" #@param ["MP4", "Frames" ]

#Merge
print("Initiating Merge ...\n")
# %cd "/content"

merge_cmd = "DeepFaceLab/main.py merge --input-dir workspace/data_dst --output-dir workspace/data_dst/merged --output-mask-dir workspace/data_dst/merged_mask --aligned-dir workspace/data_dst/aligned --model-dir workspace/model --model "+Model
# !python $merge_cmd

#Output
if (Export_Format == "MP4"):
  print("\nCombining merged frames to "+ResultFileName+" ...\n")

  output_cmd = "DeepFaceLab/main.py videoed video-from-sequence --input-dir workspace/data_dst/merged --output-file workspace/"+ResultFileName+" --reference-file workspace/data_dst.mp4 --bitrate "+ResultBitRate+" --include-audio"
  # !python $output_cmd

  if (Include_Mask):
    print("\nCombining merged_mask frames to "+MaskFileName+" ...\n")

    output_cmd = "DeepFaceLab/main.py videoed video-from-sequence --input-dir workspace/data_dst/merged_mask --output-file workspace/"+MaskFileName+" --reference-file workspace/data_dst.mp4 --bitrate "+ResultBitRate
    # !python $output_cmd

#Export to Drive
if (Export_Format == "MP4"):
  print("\nExporting "+ResultFileName+" to Drive ...\n")

  copy_cmd = "--progress "+"/content/workspace/"+ResultFileName+" /content/drive/My\ Drive/"
  # !rsync $copy_cmd

  if (Include_Mask):
    print("\nExporting "+MaskFileName+" to Drive ...\n")

    copy_cmd = "--progress "+"/content/workspace/"+MaskFileName+" /content/drive/My\ Drive/"
    # !rsync $copy_cmd

else:
  print("\nExporting merged frames to Drive ...\n")
  folderPath = "/content/drive/My Drive/"+ResultFolderName
  
  if not Path(folderPath).exists():
    print("\nCreating "+ResultFolderName+" folder in Drive ... ")
    mkdir_cmd = "/content/drive/My\ Drive/"+ResultFolderName
    # !mkdir $mkdir_cmd
  
  # %cd $folderPath
  print("\nCopying merged frames to "+ResultFolderName+" on Drive ... ")
  copy_cmd = "--progress "+"* /content/drive/My\ Drive/merged/"
  # !rsync $copy_cmd

  if (Include_Mask):
    print("\nExporting merged_mask frames to Drive ...\n")
    maskFolderPath = "/content/drive/My Drive/"+ResultMaskFolderName
    
    if not Path(maskFolderPath).exists():
      print("\nCreating "+ResultMaskFolderName+" folder in Drive ... ")
      mkdir_cmd = "/content/drive/My\ Drive/"+ResultMaskFolderName
      # !mkdir $mkdir_cmd
    
    # %cd $maskFolderPath
    print("\nCopying merged_mask frames to "+ResultMaskFolderName+" on Drive ... ")
    copy_cmd = "--progress "+"* /content/drive/My\ Drive/merged_mask/"
    # !rsync $copy_cmd

print("\nDONE!")

# %%
#@title Merge
Model = "SAEHD" #@param ["SAEHD", "Quick96" ]

cmd = "DeepFaceLab/main.py merge --input-dir workspace/data_dst --output-dir workspace/data_dst/merged --output-mask-dir workspace/data_dst/merged_mask --aligned-dir workspace/data_dst/aligned --model-dir workspace/model --model "+Model

# %cd "/content"
# !python $cmd

# %%
#@title Video from frames
Mode = "result video" #@param ["result video", "result_mask video"]
Copy_to_Drive = True #@param {type:"boolean"}


if Mode == "result video":
  # !python DeepFaceLab/main.py videoed video-from-sequence --input-dir workspace/data_dst/merged --output-file workspace/result.mp4 --reference-file workspace/data_dst.mp4 --include-audio
  if Copy_to_Drive:
    copy_cmd = "--progress "+"/content/workspace/result.mp4 /content/drive/My\ Drive/"
    # !rsync $copy_cmd 
elif Mode == "result_mask video":
  # !python DeepFaceLab/main.py videoed video-from-sequence --input-dir workspace/data_dst/merged_mask --output-file workspace/result_mask.mp4 --reference-file workspace/data_dst.mp4
  if Copy_to_Drive:
    copy_cmd = "--progress "+"/content/workspace/result_mask.mp4 /content/drive/My\ Drive/"
    # !rsync $copy_cmd
